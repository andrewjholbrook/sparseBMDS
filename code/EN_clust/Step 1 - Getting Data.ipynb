# %% [markdown]
# # Goal
#
# Download data from arXiv. Note arXiv has an API with a nice guide: https://info.arxiv.org/help/api/index.html
#
# There exists a dataset for ML articles, but it contains neither author nor time fields, which makes it seem less-than-useful for our purposes: https://huggingface.co/datasets/CShorten/ML-ArXiv-Papers
#
# We'll choose a few sub-subjects from the big list https://github.com/Mahdisadjadi/arxivscraper/blob/main/categories_v2.md, as well as a few date ranges.

# %% [raw]
# arXivScrape_astro-ph.pkl
# arXivScrape_cond-mat.pkl
# arXivScrape_cs.ai.pkl
# arXivScrape_cs.cg.pkl
# arXivScrape_cs.cl.pkl
# arXivScrape_cs.cr.pkl
# arXivScrape_cs.cv.pkl
# arXivScrape_cs.dm.pkl
# arXivScrape_cs.lg.pkl
# arXivScrape_cs.se.pkl
# arXivScrape_cs.si.pkl
# arXivScrape_eess.as.pkl
# arXivScrape_eess.iv.pkl
# arXivScrape_eess.sp.pkl
# arXivScrape_eess.sy.pkl
# arXivScrape_hep.pkl
# arXivScrape_math.ap.pkl
# arXivScrape_math.at.pkl
# arXivScrape_math.co.pkl
# arXivScrape_math.gm.pkl
# arXivScrape_math.mp.pkl
# arXivScrape_math.na.pkl
# arXivScrape_math.nt.pkl
# arXivScrape_math.oc.pkl
# arXivScrape_math.pr.pkl
# arXivScrape_math.rt.pkl
# arXivScrape_math.st.pkl
# arXivScrape_physics.optics.pkl
# arXivScrape_quant-ph.pkl
# arXivScrape_stat.me.pkl
# arXivScrape_stat.ml.pkl
# cs.ds
# cs.ir
#
# Next:
#
# math.ct
# math.dg
# math.ds
# math.fa
# math.gr
#
# math.lo
# math.oc
# gr-qc

# %%
#pip install arxivscraper

# %%
#pip install unidecode

# %%
import arxivscraper
import pandas as pd
import time
import pickle
from unidecode import unidecode
from datetime import date, timedelta
import glob
from collections import Counter

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/amisheth/sparseBMDS/code/EN_clust'

# %%
#pip install -U numpy

# %%
#pip uninstall sentence-transformers --yes

# %% [markdown]
# # checking that this works...

# %%
# Trying out the following: https://github.com/Mahdisadjadi/arxivscraper
scraper = arxivscraper.Scraper(category = 'stat', date_from = '2024-01-10', date_until = '2024-01-11',
                               filters = {'categories' : ['ML']})
# for _ in range(5):  # Example: Scrape in small batches
#     output = scraper.scrape()
#     time.sleep(10) 
output = scraper.scrape()
cols = ('id', 'title', 'categories', 'abstract', 'doi', 'created', 'updated', 'authors')
df = pd.DataFrame(output, columns = cols)
df = df.drop_duplicates(subset = ['id'])
df['authors'] = [ [unidecode(x) for x in y] for y in df['authors'] ]
df.shape
# Out:
# fetching up to  1000 records...
# fetching is completed in 3.0 seconds.
# Total number of records 28
# (28, 8)

# %%
df
# Out:
#            id                                              title  \
# 0  2305.11913  machine learning for phase-resolved reconstruc...
# 1  2310.07425  statistical properties of speckle patterns for...
# 2  2401.03736  lessons learned: reproducibility, replicabilit...
# 3  2401.04125  deepphysinet: bridging deep learning and atmos...
# 4  2401.04431  sea wave data reconstruction using micro-seism...
#
#                                         categories  \
# 0                        physics.ao-ph cs.ai cs.lg
# 1  physics.optics cond-mat.stat-mech physics.ao-ph
# 2                              cs.lg physics.ao-ph
# 3                        physics.ao-ph cs.ai cs.lg
# 4              physics.ins-det cs.lg physics.ao-ph
#
#                                             abstract  \
# 0  accurate short-term predictions of phase-resol...
# 1  the statistical properties of speckle patterns...
# 2  while extensive guidance exists for ensuring t...
# 3  accurate weather forecasting holds significant...
# 4  sea wave monitoring is key in many application...
#
#                               doi     created     updated  \
# 0  10.1016/j.oceaneng.2023.116059  2023-05-18  2023-10-18
# 1     10.1103/physreva.109.013501  2023-10-11  2024-01-10
# 2                                  2024-01-08  2024-01-09
# 3                                  2024-01-04
# 4       10.3389/fmars.2022.798167  2024-01-09
#
#                                              authors
# 0  [svenja ehlers, marco klein, alexander heinlei...
# 1  [fernando l. metz, cristian bonatto, sandra d....
# 2                     [milton s. gomez, tom beucler]
# 3  [wenyuan li, zili liu, keyan chen, hao chen, s...
# 4  [lorenzo iafolla, emiliano fiorenza, massimo c...

# %% [markdown]
# # Let's go

# %%
## set parameters here
#first_month = (2017, 12) # inclusively
first_month = (2018, 1) # inclusively
last_month = (2024, 3)   # exclusively
#last_month = (2021, 5)   # exclusively

cat = 'q-bio'
subcat = 'BM'

## build date range tuples, month by month
y = first_month[0]
m = first_month[1]
date_tuples = []
while True:
    start_dt = date(y, m, 1)
    m += 1
    if m > 12:
        m = 1
        y += 1
    end_dt = date(y, m, 1)
    date_tuples.append((start_dt, end_dt))
    if y == last_month[0] and m == last_month[1]:
        break

## fetch and save per month
for date_range in date_tuples:
    dt = date_range[0]
    df = pd.DataFrame()
    while dt < date_range[1]: # day by day until next month
        scraper = arxivscraper.Scraper(category = cat, date_from = str(dt), date_until = str(dt), 
                                       filters = {'categories':[subcat]})
        output = scraper.scrape();
        cols = ('id', 'title', 'categories', 'abstract', 'doi', 'created', 'updated', 'authors')
        try:
            df = pd.concat([df, pd.DataFrame(output, columns = cols)])
            print(dt, df.shape)
        except:
            print('skipping', str(dt))
        time.sleep(10) # respect arXiv rules    
        dt = dt + timedelta(days = 1) 
    dt = dt - timedelta(days = 1)
    #df = df.drop_duplicates(subset=['id'])
    #
    name = "arXivScrape_" + subcat + "_" + str(dt).split('-')[0] + "_" + str(dt).split('-')[1] + ".pkl"
    df.to_pickle(name)
# Out:
# fetching up to  1000 records...
# fetching is completed in 3.2 seconds.
# Total number of records 0
# 2018-01-01 (0, 8)
# fetching up to  1000 records...
# skipping 2018-01-02
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 2
# 2018-01-03 (2, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 1
# 2018-01-04 (3, 8)
# fetching up to  1000 records...
# skipping 2018-01-05
# fetching up to  1000 records...
# skipping 2018-01-06
# fetching up to  1000 records...
# skipping 2018-01-07
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 1
# 2018-01-08 (4, 8)
# fetching up to  1000 records...
# fetching is completed in 2.4 seconds.
# Total number of records 2
# 2018-01-09 (6, 8)
# fetching up to  1000 records...
# fetching is completed in 1.9 seconds.
# Total number of records 0
# 2018-01-10 (6, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 1
# 2018-01-11 (7, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 0
# 2018-01-12 (7, 8)
# fetching up to  1000 records...
# skipping 2018-01-13
# fetching up to  1000 records...
# skipping 2018-01-14
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 0
# 2018-01-15 (7, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 1
# 2018-01-16 (8, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 3
# 2018-01-17 (11, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 0
# 2018-01-18 (11, 8)
# fetching up to  1000 records...
# fetching is completed in 1.9 seconds.
# Total number of records 0
# 2018-01-19 (11, 8)
# fetching up to  1000 records...
# skipping 2018-01-20
# fetching up to  1000 records...
# skipping 2018-01-21
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 0
# 2018-01-22 (11, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 0
# 2018-01-23 (11, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 1
# 2018-01-24 (12, 8)
# fetching up to  1000 records...
# fetching is completed in 2.5 seconds.
# Total number of records 1
# 2018-01-25 (13, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 0
# 2018-01-26 (13, 8)
# fetching up to  1000 records...
# skipping 2018-01-27
# fetching up to  1000 records...
# skipping 2018-01-28
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 0
# 2018-01-29 (13, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 1
# 2018-01-30 (14, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 2
# 2018-01-31 (16, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2018-02-01 (0, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 1
# 2018-02-02 (1, 8)
# fetching up to  1000 records...
# skipping 2018-02-03
# fetching up to  1000 records...
# skipping 2018-02-04
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2018-02-05 (1, 8)
# fetching up to  1000 records...
# fetching is completed in 2.5 seconds.
# Total number of records 2
# 2018-02-06 (3, 8)
# fetching up to  1000 records...
# fetching is completed in 2.5 seconds.
# Total number of records 2
# 2018-02-07 (5, 8)
# fetching up to  1000 records...
# fetching is completed in 2.8 seconds.
# Total number of records 1
# 2018-02-08 (6, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2018-02-09 (6, 8)
# fetching up to  1000 records...
# skipping 2018-02-10
# fetching up to  1000 records...
# skipping 2018-02-11
# fetching up to  1000 records...
# fetching is completed in 3.1 seconds.
# Total number of records 0
# 2018-02-12 (6, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 1
# 2018-02-13 (7, 8)
# fetching up to  1000 records...
# fetching is completed in 2.4 seconds.
# Total number of records 3
# 2018-02-14 (10, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2018-02-15 (10, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 1
# 2018-02-16 (11, 8)
# fetching up to  1000 records...
# skipping 2018-02-17
# fetching up to  1000 records...
# skipping 2018-02-18
# fetching up to  1000 records...
# fetching is completed in 2.7 seconds.
# Total number of records 0
# 2018-02-19 (11, 8)
# fetching up to  1000 records...
# fetching is completed in 2.6 seconds.
# Total number of records 2
# 2018-02-20 (13, 8)
# fetching up to  1000 records...
# fetching is completed in 2.4 seconds.
# Total number of records 1
# 2018-02-21 (14, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 0
# 2018-02-22 (14, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2018-02-23 (14, 8)
# fetching up to  1000 records...
# skipping 2018-02-24
# fetching up to  1000 records...
# skipping 2018-02-25
# fetching up to  1000 records...
# fetching is completed in 1.9 seconds.
# Total number of records 0
# 2018-02-26 (14, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 1
# 2018-02-27 (15, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2018-02-28 (15, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 2
# 2018-03-01 (2, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 1
# 2018-03-02 (3, 8)
# fetching up to  1000 records...
# skipping 2018-03-03
# fetching up to  1000 records...
# skipping 2018-03-04
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2018-03-05 (3, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 1
# 2018-03-06 (4, 8)
# fetching up to  1000 records...
# fetching is completed in 2.5 seconds.
# Total number of records 1
# 2018-03-07 (5, 8)
# fetching up to  1000 records...
# fetching is completed in 3.2 seconds.
# Total number of records 1
# 2018-03-08 (6, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 1
# 2018-03-09 (7, 8)
# fetching up to  1000 records...
# skipping 2018-03-10
# fetching up to  1000 records...
# skipping 2018-03-11
# fetching up to  1000 records...
# fetching is completed in 3.4 seconds.
# Total number of records 1
# 2018-03-12 (8, 8)
# fetching up to  1000 records...
# fetching is completed in 22.3 seconds.
# Total number of records 1
# 2018-03-13 (9, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 6
# 2018-03-14 (15, 8)
# fetching up to  1000 records...
# fetching is completed in 2.6 seconds.
# Total number of records 1
# 2018-03-15 (16, 8)
# fetching up to  1000 records...
# fetching is completed in 2.4 seconds.
# Total number of records 1
# 2018-03-16 (17, 8)
# fetching up to  1000 records...
# skipping 2018-03-17
# fetching up to  1000 records...
# skipping 2018-03-18
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 0
# 2018-03-19 (17, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 2
# 2018-03-20 (19, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 1
# 2018-03-21 (20, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 0
# 2018-03-22 (20, 8)
# fetching up to  1000 records...
# fetching is completed in 1.9 seconds.
# Total number of records 0
# 2018-03-23 (20, 8)
# fetching up to  1000 records...
# skipping 2018-03-24
# fetching up to  1000 records...
# skipping 2018-03-25
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 2
# 2018-03-26 (22, 8)
# fetching up to  1000 records...
# fetching is completed in 1.9 seconds.
# Total number of records 0
# 2018-03-27 (22, 8)
# fetching up to  1000 records...
# fetching is completed in 3.9 seconds.
# Total number of records 3
# 2018-03-28 (25, 8)
# fetching up to  1000 records...
# fetching is completed in 2.8 seconds.
# Total number of records 0
# 2018-03-29 (25, 8)
# fetching up to  1000 records...
# fetching is completed in 7.9 seconds.
# Total number of records 1
# 2018-03-30 (26, 8)
# fetching up to  1000 records...
# skipping 2018-03-31
# fetching up to  1000 records...
# skipping 2018-04-01
# fetching up to  1000 records...
# fetching is completed in 2.4 seconds.
# Total number of records 0
# 2018-04-02 (0, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 0
# 2018-04-03 (0, 8)
# fetching up to  1000 records...
# fetching is completed in 13.6 seconds.
# Total number of records 2
# 2018-04-04 (2, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 1
# 2018-04-05 (3, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 1
# 2018-04-06 (4, 8)
# fetching up to  1000 records...
# skipping 2018-04-07
# fetching up to  1000 records...
# skipping 2018-04-08
# fetching up to  1000 records...
# fetching is completed in 3.3 seconds.
# Total number of records 0
# 2018-04-09 (4, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 0
# 2018-04-10 (4, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 1
# 2018-04-11 (5, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2018-04-12 (5, 8)
# fetching up to  1000 records...
# fetching is completed in 5.3 seconds.
# Total number of records 1
# 2018-04-13 (6, 8)
# fetching up to  1000 records...
# skipping 2018-04-14
# fetching up to  1000 records...
# skipping 2018-04-15
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 2
# 2018-04-16 (8, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 1
# 2018-04-17 (9, 8)
# fetching up to  1000 records...
# fetching is completed in 9.7 seconds.
# Total number of records 2
# 2018-04-18 (11, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2018-04-19 (11, 8)
# fetching up to  1000 records...
# fetching is completed in 6.0 seconds.
# Total number of records 0
# 2018-04-20 (11, 8)
# fetching up to  1000 records...
# skipping 2018-04-21
# fetching up to  1000 records...
# skipping 2018-04-22
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 2
# 2018-04-23 (13, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 1
# 2018-04-24 (14, 8)
# fetching up to  1000 records...
# fetching is completed in 2.5 seconds.
# Total number of records 0
# 2018-04-25 (14, 8)
# fetching up to  1000 records...
# fetching is completed in 1.9 seconds.
# Total number of records 1
# 2018-04-26 (15, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2018-04-27 (15, 8)
# fetching up to  1000 records...
# skipping 2018-04-28
# fetching up to  1000 records...
# skipping 2018-04-29
# fetching up to  1000 records...
# fetching is completed in 2.6 seconds.
# Total number of records 0
# 2018-04-30 (15, 8)
# fetching up to  1000 records...
# fetching is completed in 2.4 seconds.
# Total number of records 2
# 2018-05-01 (2, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 2
# 2018-05-02 (4, 8)
# fetching up to  1000 records...
# fetching is completed in 10.4 seconds.
# Total number of records 0
# 2018-05-03 (4, 8)
# fetching up to  1000 records...
# fetching is completed in 3.6 seconds.
# Total number of records 0
# 2018-05-04 (4, 8)
# fetching up to  1000 records...
# skipping 2018-05-05
# fetching up to  1000 records...
# skipping 2018-05-06
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 0
# 2018-05-07 (4, 8)
# fetching up to  1000 records...
# fetching is completed in 3.7 seconds.
# Total number of records 2
# 2018-05-08 (6, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2018-05-09 (6, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 0
# 2018-05-10 (6, 8)
# fetching up to  1000 records...
# fetching is completed in 2.5 seconds.
# Total number of records 1
# 2018-05-11 (7, 8)
# fetching up to  1000 records...
# skipping 2018-05-12
# fetching up to  1000 records...
# skipping 2018-05-13
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 0
# 2018-05-14 (7, 8)
# fetching up to  1000 records...
# fetching is completed in 4.4 seconds.
# Total number of records 2
# 2018-05-15 (9, 8)
# fetching up to  1000 records...
# fetching is completed in 2.9 seconds.
# Total number of records 2
# 2018-05-16 (11, 8)
# fetching up to  1000 records...
# fetching is completed in 8.5 seconds.
# Total number of records 1
# 2018-05-17 (12, 8)
# fetching up to  1000 records...
# fetching is completed in 2.7 seconds.
# Total number of records 1
# 2018-05-18 (13, 8)
# fetching up to  1000 records...
# skipping 2018-05-19
# fetching up to  1000 records...
# skipping 2018-05-20
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 0
# 2018-05-21 (13, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 2
# 2018-05-22 (15, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 0
# 2018-05-23 (15, 8)
# fetching up to  1000 records...
# fetching is completed in 2.5 seconds.
# Total number of records 1
# 2018-05-24 (16, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2018-05-25 (16, 8)
# fetching up to  1000 records...
# skipping 2018-05-26
# fetching up to  1000 records...
# skipping 2018-05-27
# fetching up to  1000 records...
# fetching is completed in 2.7 seconds.
# Total number of records 1
# 2018-05-28 (17, 8)
# fetching up to  1000 records...
# fetching is completed in 2.5 seconds.
# Total number of records 1
# 2018-05-29 (18, 8)
# fetching up to  1000 records...
# fetching is completed in 3.0 seconds.
# Total number of records 2
# 2018-05-30 (20, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 0
# 2018-05-31 (20, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2018-06-01 (0, 8)
# fetching up to  1000 records...
# skipping 2018-06-02
# fetching up to  1000 records...
# skipping 2018-06-03
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 1
# 2018-06-04 (1, 8)
# fetching up to  1000 records...
# fetching is completed in 2.6 seconds.
# Total number of records 0
# 2018-06-05 (1, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 3
# 2018-06-06 (4, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 0
# 2018-06-07 (4, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 0
# 2018-06-08 (4, 8)
# fetching up to  1000 records...
# skipping 2018-06-09
# fetching up to  1000 records...
# skipping 2018-06-10
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2018-06-11 (4, 8)
# fetching up to  1000 records...
# fetching is completed in 2.5 seconds.
# Total number of records 3
# 2018-06-12 (7, 8)
# fetching up to  1000 records...
# fetching is completed in 2.4 seconds.
# Total number of records 4
# 2018-06-13 (11, 8)
# fetching up to  1000 records...
# fetching is completed in 2.6 seconds.
# Total number of records 0
# 2018-06-14 (11, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 1
# 2018-06-15 (12, 8)
# fetching up to  1000 records...
# skipping 2018-06-16
# fetching up to  1000 records...
# skipping 2018-06-17
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 0
# 2018-06-18 (12, 8)
# fetching up to  1000 records...
# fetching is completed in 1.9 seconds.
# Total number of records 1
# 2018-06-19 (13, 8)
# fetching up to  1000 records...
# fetching is completed in 5.3 seconds.
# Total number of records 1
# 2018-06-20 (14, 8)
# fetching up to  1000 records...
# fetching is completed in 3.3 seconds.
# Total number of records 0
# 2018-06-21 (14, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2018-06-22 (14, 8)
# fetching up to  1000 records...
# skipping 2018-06-23
# fetching up to  1000 records...
# fetching is completed in 1.9 seconds.
# Total number of records 0
# 2018-06-24 (14, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 0
# 2018-06-25 (14, 8)
# fetching up to  1000 records...
# fetching is completed in 2.8 seconds.
# Total number of records 0
# 2018-06-26 (14, 8)
# fetching up to  1000 records...
# fetching is completed in 2.5 seconds.
# Total number of records 3
# 2018-06-27 (17, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 0
# 2018-06-28 (17, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 3
# 2018-06-29 (20, 8)
# fetching up to  1000 records...
# skipping 2018-06-30
# fetching up to  1000 records...
# skipping 2018-07-01
# fetching up to  1000 records...
# fetching is completed in 11.8 seconds.
# Total number of records 3
# 2018-07-02 (3, 8)
# fetching up to  1000 records...
# fetching is completed in 3.1 seconds.
# Total number of records 3
# 2018-07-03 (6, 8)
# fetching up to  1000 records...
# fetching is completed in 2.7 seconds.
# Total number of records 3
# 2018-07-04 (9, 8)
# fetching up to  1000 records...
# fetching is completed in 2.5 seconds.
# Total number of records 0
# 2018-07-05 (9, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2018-07-06 (9, 8)
# fetching up to  1000 records...
# skipping 2018-07-07
# fetching up to  1000 records...
# skipping 2018-07-08
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 1
# 2018-07-09 (10, 8)
# fetching up to  1000 records...
# fetching is completed in 2.5 seconds.
# Total number of records 0
# 2018-07-10 (10, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 0
# 2018-07-11 (10, 8)
# fetching up to  1000 records...
# fetching is completed in 7.1 seconds.
# Total number of records 2
# 2018-07-12 (12, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2018-07-13 (12, 8)
# fetching up to  1000 records...
# skipping 2018-07-14
# fetching up to  1000 records...
# skipping 2018-07-15
# fetching up to  1000 records...
# fetching is completed in 2.4 seconds.
# Total number of records 0
# 2018-07-16 (12, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 1
# 2018-07-17 (13, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 2
# 2018-07-18 (15, 8)
# fetching up to  1000 records...
# fetching is completed in 1.9 seconds.
# Total number of records 0
# 2018-07-19 (15, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 1
# 2018-07-20 (16, 8)
# fetching up to  1000 records...
# skipping 2018-07-21
# fetching up to  1000 records...
# skipping 2018-07-22
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 1
# 2018-07-23 (17, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 1
# 2018-07-24 (18, 8)
# fetching up to  1000 records...
# fetching is completed in 3.2 seconds.
# Total number of records 0
# 2018-07-25 (18, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2018-07-26 (18, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 1
# 2018-07-27 (19, 8)
# fetching up to  1000 records...
# skipping 2018-07-28
# fetching up to  1000 records...
# skipping 2018-07-29
# fetching up to  1000 records...
# fetching is completed in 2.8 seconds.
# Total number of records 2
# 2018-07-30 (21, 8)
# fetching up to  1000 records...
# fetching is completed in 4.6 seconds.
# Total number of records 0
# 2018-07-31 (21, 8)
# fetching up to  1000 records...
# fetching is completed in 2.4 seconds.
# Total number of records 1
# 2018-08-01 (1, 8)
# fetching up to  1000 records...
# fetching is completed in 3.2 seconds.
# Total number of records 0
# 2018-08-02 (1, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 0
# 2018-08-03 (1, 8)
# fetching up to  1000 records...
# skipping 2018-08-04
# fetching up to  1000 records...
# skipping 2018-08-05
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 1
# 2018-08-06 (2, 8)
# fetching up to  1000 records...
# fetching is completed in 2.9 seconds.
# Total number of records 0
# 2018-08-07 (2, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2018-08-08 (2, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 1
# 2018-08-09 (3, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 0
# 2018-08-10 (3, 8)
# fetching up to  1000 records...
# skipping 2018-08-11
# fetching up to  1000 records...
# skipping 2018-08-12
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 2
# 2018-08-13 (5, 8)
# fetching up to  1000 records...
# fetching is completed in 2.6 seconds.
# Total number of records 3
# 2018-08-14 (8, 8)
# fetching up to  1000 records...
# fetching is completed in 4.0 seconds.
# Total number of records 3
# 2018-08-15 (11, 8)
# fetching up to  1000 records...
# fetching is completed in 2.5 seconds.
# Total number of records 0
# 2018-08-16 (11, 8)
# fetching up to  1000 records...
# fetching is completed in 2.4 seconds.
# Total number of records 1
# 2018-08-17 (12, 8)
# fetching up to  1000 records...
# skipping 2018-08-18
# fetching up to  1000 records...
# skipping 2018-08-19
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 1
# 2018-08-20 (13, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2018-08-21 (13, 8)
# fetching up to  1000 records...
# fetching is completed in 2.5 seconds.
# Total number of records 0
# 2018-08-22 (13, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 1
# 2018-08-23 (14, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 1
# 2018-08-24 (15, 8)
# fetching up to  1000 records...
# skipping 2018-08-25
# fetching up to  1000 records...
# skipping 2018-08-26
# fetching up to  1000 records...
# fetching is completed in 2.8 seconds.
# Total number of records 1
# 2018-08-27 (16, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 3
# 2018-08-28 (19, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 3
# 2018-08-29 (22, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 2
# 2018-08-30 (24, 8)
# fetching up to  1000 records...
# fetching is completed in 1.8 seconds.
# Total number of records 0
# 2018-08-31 (24, 8)
# fetching up to  1000 records...
# skipping 2018-09-01
# fetching up to  1000 records...
# skipping 2018-09-02
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 1
# 2018-09-03 (1, 8)
# fetching up to  1000 records...
# skipping 2018-09-04
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 3
# 2018-09-05 (4, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2018-09-06 (4, 8)
# fetching up to  1000 records...
# fetching is completed in 2.6 seconds.
# Total number of records 2
# 2018-09-07 (6, 8)
# fetching up to  1000 records...
# skipping 2018-09-08
# fetching up to  1000 records...
# skipping 2018-09-09
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 0
# 2018-09-10 (6, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 0
# 2018-09-11 (6, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 0
# 2018-09-12 (6, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 1
# 2018-09-13 (7, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2018-09-14 (7, 8)
# fetching up to  1000 records...
# skipping 2018-09-15
# fetching up to  1000 records...
# skipping 2018-09-16
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2018-09-17 (7, 8)
# fetching up to  1000 records...
# fetching is completed in 2.5 seconds.
# Total number of records 2
# 2018-09-18 (9, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 2
# 2018-09-19 (11, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 1
# 2018-09-20 (12, 8)
# fetching up to  1000 records...
# fetching is completed in 1.9 seconds.
# Total number of records 1
# 2018-09-21 (13, 8)
# fetching up to  1000 records...
# skipping 2018-09-22
# fetching up to  1000 records...
# skipping 2018-09-23
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 1
# 2018-09-24 (14, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 1
# 2018-09-25 (15, 8)
# fetching up to  1000 records...
# fetching is completed in 2.5 seconds.
# Total number of records 1
# 2018-09-26 (16, 8)
# fetching up to  1000 records...
# fetching is completed in 2.4 seconds.
# Total number of records 1
# 2018-09-27 (17, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 3
# 2018-09-28 (20, 8)
# fetching up to  1000 records...
# skipping 2018-09-29
# fetching up to  1000 records...
# skipping 2018-09-30
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 3
# 2018-10-01 (3, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 2
# 2018-10-02 (5, 8)
# fetching up to  1000 records...
# fetching is completed in 2.4 seconds.
# Total number of records 1
# 2018-10-03 (6, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 4
# 2018-10-04 (10, 8)
# fetching up to  1000 records...
# fetching is completed in 2.4 seconds.
# Total number of records 0
# 2018-10-05 (10, 8)
# fetching up to  1000 records...
# skipping 2018-10-06
# fetching up to  1000 records...
# skipping 2018-10-07
# fetching up to  1000 records...
# fetching is completed in 1.9 seconds.
# Total number of records 1
# 2018-10-08 (11, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 3
# 2018-10-09 (14, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 1
# 2018-10-10 (15, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 0
# 2018-10-11 (15, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2018-10-12 (15, 8)
# fetching up to  1000 records...
# skipping 2018-10-13
# fetching up to  1000 records...
# skipping 2018-10-14
# fetching up to  1000 records...
# fetching is completed in 3.0 seconds.
# Total number of records 1
# 2018-10-15 (16, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 1
# 2018-10-16 (17, 8)
# fetching up to  1000 records...
# fetching is completed in 2.5 seconds.
# Total number of records 5
# 2018-10-17 (22, 8)
# fetching up to  1000 records...
# fetching is completed in 3.3 seconds.
# Total number of records 1
# 2018-10-18 (23, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 2
# 2018-10-19 (25, 8)
# fetching up to  1000 records...
# skipping 2018-10-20
# fetching up to  1000 records...
# skipping 2018-10-21
# fetching up to  1000 records...
# fetching is completed in 2.4 seconds.
# Total number of records 0
# 2018-10-22 (25, 8)
# fetching up to  1000 records...
# fetching is completed in 2.4 seconds.
# Total number of records 2
# 2018-10-23 (27, 8)
# fetching up to  1000 records...
# fetching is completed in 3.0 seconds.
# Total number of records 1
# 2018-10-24 (28, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2018-10-25 (28, 8)
# fetching up to  1000 records...
# fetching is completed in 2.4 seconds.
# Total number of records 1
# 2018-10-26 (29, 8)
# fetching up to  1000 records...
# skipping 2018-10-27
# fetching up to  1000 records...
# skipping 2018-10-28
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 0
# 2018-10-29 (29, 8)
# fetching up to  1000 records...
# fetching is completed in 2.7 seconds.
# Total number of records 2
# 2018-10-30 (31, 8)
# fetching up to  1000 records...
# fetching is completed in 2.5 seconds.
# Total number of records 1
# 2018-10-31 (32, 8)
# fetching up to  1000 records...
# fetching is completed in 2.4 seconds.
# Total number of records 0
# 2018-11-01 (0, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 0
# 2018-11-02 (0, 8)
# fetching up to  1000 records...
# skipping 2018-11-03
# fetching up to  1000 records...
# skipping 2018-11-04
# fetching up to  1000 records...
# fetching is completed in 2.8 seconds.
# Total number of records 2
# 2018-11-05 (2, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 4
# 2018-11-06 (6, 8)
# fetching up to  1000 records...
# fetching is completed in 3.0 seconds.
# Total number of records 2
# 2018-11-07 (8, 8)
# fetching up to  1000 records...
# fetching is completed in 2.4 seconds.
# Total number of records 0
# 2018-11-08 (8, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2018-11-09 (8, 8)
# fetching up to  1000 records...
# skipping 2018-11-10
# fetching up to  1000 records...
# skipping 2018-11-11
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 0
# 2018-11-12 (8, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 0
# 2018-11-13 (8, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 2
# 2018-11-14 (10, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 0
# 2018-11-15 (10, 8)
# fetching up to  1000 records...
# fetching is completed in 3.1 seconds.
# Total number of records 0
# 2018-11-16 (10, 8)
# fetching up to  1000 records...
# skipping 2018-11-17
# fetching up to  1000 records...
# skipping 2018-11-18
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 0
# 2018-11-19 (10, 8)
# fetching up to  1000 records...
# fetching is completed in 2.7 seconds.
# Total number of records 0
# 2018-11-20 (10, 8)
# fetching up to  1000 records...
# fetching is completed in 2.5 seconds.
# Total number of records 3
# 2018-11-21 (13, 8)
# fetching up to  1000 records...
# fetching is completed in 2.5 seconds.
# Total number of records 0
# 2018-11-22 (13, 8)
# fetching up to  1000 records...
# skipping 2018-11-23
# fetching up to  1000 records...
# skipping 2018-11-24
# fetching up to  1000 records...
# skipping 2018-11-25
# fetching up to  1000 records...
# fetching is completed in 10.6 seconds.
# Total number of records 3
# 2018-11-26 (16, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 0
# 2018-11-27 (16, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 1
# 2018-11-28 (17, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2018-11-29 (17, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 1
# 2018-11-30 (18, 8)
# fetching up to  1000 records...
# skipping 2018-12-01
# fetching up to  1000 records...
# skipping 2018-12-02
# fetching up to  1000 records...
# fetching is completed in 2.6 seconds.
# Total number of records 3
# 2018-12-03 (3, 8)
# fetching up to  1000 records...
# fetching is completed in 2.4 seconds.
# Total number of records 0
# 2018-12-04 (3, 8)
# fetching up to  1000 records...
# fetching is completed in 2.5 seconds.
# Total number of records 2
# 2018-12-05 (5, 8)
# fetching up to  1000 records...
# fetching is completed in 2.4 seconds.
# Total number of records 1
# 2018-12-06 (6, 8)
# fetching up to  1000 records...
# fetching is completed in 2.5 seconds.
# Total number of records 0
# 2018-12-07 (6, 8)
# fetching up to  1000 records...
# skipping 2018-12-08
# fetching up to  1000 records...
# skipping 2018-12-09
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 2
# 2018-12-10 (8, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 0
# 2018-12-11 (8, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 0
# 2018-12-12 (8, 8)
# fetching up to  1000 records...
# fetching is completed in 1.9 seconds.
# Total number of records 0
# 2018-12-13 (8, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 1
# 2018-12-14 (9, 8)
# fetching up to  1000 records...
# skipping 2018-12-15
# fetching up to  1000 records...
# skipping 2018-12-16
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 1
# 2018-12-17 (10, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 2
# 2018-12-18 (12, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 0
# 2018-12-19 (12, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2018-12-20 (12, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 2
# 2018-12-21 (14, 8)
# fetching up to  1000 records...
# skipping 2018-12-22
# fetching up to  1000 records...
# skipping 2018-12-23
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2018-12-24 (14, 8)
# fetching up to  1000 records...
# skipping 2018-12-25
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 2
# 2018-12-26 (16, 8)
# fetching up to  1000 records...
# fetching is completed in 2.9 seconds.
# Total number of records 1
# 2018-12-27 (17, 8)
# fetching up to  1000 records...
# skipping 2018-12-28
# fetching up to  1000 records...
# skipping 2018-12-29
# fetching up to  1000 records...
# skipping 2018-12-30
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 1
# 2018-12-31 (18, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 1
# 2019-01-01 (1, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2019-01-02 (1, 8)
# fetching up to  1000 records...
# fetching is completed in 1.9 seconds.
# Total number of records 0
# 2019-01-03 (1, 8)
# fetching up to  1000 records...
# fetching is completed in 1.9 seconds.
# Total number of records 0
# 2019-01-04 (1, 8)
# fetching up to  1000 records...
# skipping 2019-01-05
# fetching up to  1000 records...
# skipping 2019-01-06
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 3
# 2019-01-07 (4, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 0
# 2019-01-08 (4, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 0
# 2019-01-09 (4, 8)
# fetching up to  1000 records...
# fetching is completed in 1.9 seconds.
# Total number of records 1
# 2019-01-10 (5, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 2
# 2019-01-11 (7, 8)
# fetching up to  1000 records...
# skipping 2019-01-12
# fetching up to  1000 records...
# skipping 2019-01-13
# fetching up to  1000 records...
# fetching is completed in 1.9 seconds.
# Total number of records 0
# 2019-01-14 (7, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 0
# 2019-01-15 (7, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 0
# 2019-01-16 (7, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2019-01-17 (7, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 1
# 2019-01-18 (8, 8)
# fetching up to  1000 records...
# skipping 2019-01-19
# fetching up to  1000 records...
# skipping 2019-01-20
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 0
# 2019-01-21 (8, 8)
# fetching up to  1000 records...
# skipping 2019-01-22
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 2
# 2019-01-23 (10, 8)
# fetching up to  1000 records...
# fetching is completed in 6.0 seconds.
# Total number of records 1
# 2019-01-24 (11, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 0
# 2019-01-25 (11, 8)
# fetching up to  1000 records...
# skipping 2019-01-26
# fetching up to  1000 records...
# skipping 2019-01-27
# fetching up to  1000 records...
# fetching is completed in 1.9 seconds.
# Total number of records 0
# 2019-01-28 (11, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 0
# 2019-01-29 (11, 8)
# fetching up to  1000 records...
# fetching is completed in 3.0 seconds.
# Total number of records 0
# 2019-01-30 (11, 8)
# fetching up to  1000 records...
# fetching is completed in 11.7 seconds.
# Total number of records 0
# 2019-01-31 (11, 8)
# fetching up to  1000 records...
# fetching is completed in 8.8 seconds.
# Total number of records 1
# 2019-02-01 (1, 8)
# fetching up to  1000 records...
# skipping 2019-02-02
# fetching up to  1000 records...
# skipping 2019-02-03
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 2
# 2019-02-04 (3, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 1
# 2019-02-05 (4, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 1
# 2019-02-06 (5, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 1
# 2019-02-07 (6, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 0
# 2019-02-08 (6, 8)
# fetching up to  1000 records...
# skipping 2019-02-09
# fetching up to  1000 records...
# skipping 2019-02-10
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 0
# 2019-02-11 (6, 8)
# fetching up to  1000 records...
# fetching is completed in 2.5 seconds.
# Total number of records 3
# 2019-02-12 (9, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2019-02-13 (9, 8)
# fetching up to  1000 records...
# fetching is completed in 1.9 seconds.
# Total number of records 0
# 2019-02-14 (9, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 0
# 2019-02-15 (9, 8)
# fetching up to  1000 records...
# skipping 2019-02-16
# fetching up to  1000 records...
# skipping 2019-02-17
# fetching up to  1000 records...
# fetching is completed in 2.4 seconds.
# Total number of records 0
# 2019-02-18 (9, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 2
# 2019-02-19 (11, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 2
# 2019-02-20 (13, 8)
# fetching up to  1000 records...
# fetching is completed in 3.8 seconds.
# Total number of records 1
# 2019-02-21 (14, 8)
# fetching up to  1000 records...
# fetching is completed in 10.0 seconds.
# Total number of records 1
# 2019-02-22 (15, 8)
# fetching up to  1000 records...
# skipping 2019-02-23
# fetching up to  1000 records...
# skipping 2019-02-24
# fetching up to  1000 records...
# fetching is completed in 1.9 seconds.
# Total number of records 0
# 2019-02-25 (15, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 0
# 2019-02-26 (15, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 2
# 2019-02-27 (17, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 1
# 2019-02-28 (18, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 0
# 2019-03-01 (0, 8)
# fetching up to  1000 records...
# skipping 2019-03-02
# fetching up to  1000 records...
# skipping 2019-03-03
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 1
# 2019-03-04 (1, 8)
# fetching up to  1000 records...
# fetching is completed in 2.6 seconds.
# Total number of records 1
# 2019-03-05 (2, 8)
# fetching up to  1000 records...
# fetching is completed in 2.4 seconds.
# Total number of records 1
# 2019-03-06 (3, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 0
# 2019-03-07 (3, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 2
# 2019-03-08 (5, 8)
# fetching up to  1000 records...
# skipping 2019-03-09
# fetching up to  1000 records...
# skipping 2019-03-10
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2019-03-11 (5, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 2
# 2019-03-12 (7, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 1
# 2019-03-13 (8, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 2
# 2019-03-14 (10, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2019-03-15 (10, 8)
# fetching up to  1000 records...
# skipping 2019-03-16
# fetching up to  1000 records...
# skipping 2019-03-17
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2019-03-18 (10, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 2
# 2019-03-19 (12, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 1
# 2019-03-20 (13, 8)
# fetching up to  1000 records...
# fetching is completed in 2.4 seconds.
# Total number of records 1
# 2019-03-21 (14, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 0
# 2019-03-22 (14, 8)
# fetching up to  1000 records...
# skipping 2019-03-23
# fetching up to  1000 records...
# skipping 2019-03-24
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2019-03-25 (14, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 0
# 2019-03-26 (14, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 7
# 2019-03-27 (21, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 0
# 2019-03-28 (21, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 2
# 2019-03-29 (23, 8)
# fetching up to  1000 records...
# skipping 2019-03-30
# fetching up to  1000 records...
# skipping 2019-03-31
# fetching up to  1000 records...
# fetching is completed in 1.9 seconds.
# Total number of records 3
# 2019-04-01 (3, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 1
# 2019-04-02 (4, 8)
# fetching up to  1000 records...
# fetching is completed in 1.9 seconds.
# Total number of records 2
# 2019-04-03 (6, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2019-04-04 (6, 8)
# fetching up to  1000 records...
# fetching is completed in 5.8 seconds.
# Total number of records 1
# 2019-04-05 (7, 8)
# fetching up to  1000 records...
# skipping 2019-04-06
# fetching up to  1000 records...
# skipping 2019-04-07
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 2
# 2019-04-08 (9, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 2
# 2019-04-09 (11, 8)
# fetching up to  1000 records...
# fetching is completed in 2.7 seconds.
# Total number of records 1
# 2019-04-10 (12, 8)
# fetching up to  1000 records...
# fetching is completed in 3.2 seconds.
# Total number of records 1
# 2019-04-11 (13, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 0
# 2019-04-12 (13, 8)
# fetching up to  1000 records...
# skipping 2019-04-13
# fetching up to  1000 records...
# skipping 2019-04-14
# fetching up to  1000 records...
# fetching is completed in 2.5 seconds.
# Total number of records 1
# 2019-04-15 (14, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 1
# 2019-04-16 (15, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 1
# 2019-04-17 (16, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 0
# 2019-04-18 (16, 8)
# fetching up to  1000 records...
# fetching is completed in 1.9 seconds.
# Total number of records 0
# 2019-04-19 (16, 8)
# fetching up to  1000 records...
# skipping 2019-04-20
# fetching up to  1000 records...
# fetching is completed in 1.9 seconds.
# Total number of records 0
# 2019-04-21 (16, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 1
# 2019-04-22 (17, 8)
# fetching up to  1000 records...
# fetching is completed in 2.8 seconds.
# Total number of records 1
# 2019-04-23 (18, 8)
# fetching up to  1000 records...
# fetching is completed in 3.1 seconds.
# Total number of records 0
# 2019-04-24 (18, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 1
# 2019-04-25 (19, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 1
# 2019-04-26 (20, 8)
# fetching up to  1000 records...
# skipping 2019-04-27
# fetching up to  1000 records...
# skipping 2019-04-28
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 0
# 2019-04-29 (20, 8)
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 0
# 2019-04-30 (20, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2019-05-01 (0, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 0
# 2019-05-02 (0, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 2
# 2019-05-03 (2, 8)
# fetching up to  1000 records...
# skipping 2019-05-04
# fetching up to  1000 records...
# skipping 2019-05-05
# fetching up to  1000 records...
# fetching is completed in 1.9 seconds.
# Total number of records 0
# 2019-05-06 (2, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2019-05-07 (2, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 1
# 2019-05-08 (3, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 1
# 2019-05-09 (4, 8)
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2019-05-10 (4, 8)
# fetching up to  1000 records...
# skipping 2019-05-11
# fetching up to  1000 records...
# skipping 2019-05-12
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 1
# 2019-05-13 (5, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 3
# 2019-05-14 (8, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 0
# 2019-05-15 (8, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 0
# 2019-05-16 (8, 8)
# fetching up to  1000 records...
# fetching is completed in 2.9 seconds.
# Total number of records 0
# 2019-05-17 (8, 8)
# fetching up to  1000 records...
# skipping 2019-05-18
# fetching up to  1000 records...
# skipping 2019-05-19
# fetching up to  1000 records...
# fetching is completed in 2.0 seconds.
# Total number of records 0
# 2019-05-20 (8, 8)
# fetching up to  1000 records...
# fetching is completed in 2.2 seconds.
# Total number of records 3
# 2019-05-21 (11, 8)
# fetching up to  1000 records...
# fetching is completed in 2.8 seconds.
# Total number of records 4
# 2019-05-22 (15, 8)
# fetching up to  1000 records...
# fetching is completed in 2.1 seconds.
# Total number of records 1
# 2019-05-23 (16, 8)
# fetching up to  1000 records...
# fetching is completed in 1.9 seconds.
# Total number of records 0
# 2019-05-24 (16, 8)
# fetching up to  1000 records...
# skipping 2019-05-25
# fetching up to  1000 records...
# skipping 2019-05-26
# fetching up to  1000 records...
# fetching is completed in 2.3 seconds.
# Total number of records 1
# 2019-05-27 (17, 8)
# fetching up to  1000 records...
# fetching is completed in 2.4 seconds.
# Total number of records 0
# 2019-05-28 (17, 8)
# fetching up to  1000 records...
# fetching is completed in 1.9 seconds.
# Total number of records 2
# 2019-05-29 (19, 8)
# fetching up to  1000 records...
# fetching is completed in 2.4 seconds.
# Total number of records 1
# 2019-05-30 (20, 8)
# fetching up to  1000 records...
# fetching is completed in 3.2 seconds.
# Total number of records 0
# 2019-05-31 (20, 8)
# fetching up to  1000 records...
# skipping 2019-06-01
# fetching up to  1000 records...
# skipping 2019-06-02
# fetching up to  1000 records...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 32
#      29 while dt < date_range[1]: # day by day until next month
#      30     scraper = arxivscraper.Scraper(category = cat, date_from = str(dt), date_until = str(dt),
#      31                                    filters = {'categories':[subcat]})
# ---> 32     output = scraper.scrape();
#      33     cols = ('id', 'title', 'categories', 'abstract', 'doi', 'created', 'updated', 'authors')
#      34     try:
#
# File /usr/local/Cellar/jupyterlab/4.2.3/libexec/lib/python3.12/site-packages/arxivscraper/arxivscraper.py:185, in Scraper.scrape(self)
#     183 print("fetching up to ", 1000 * k, "records...")
#     184 try:
# --> 185     response = urlopen(url)
#     186 except HTTPError as e:
#     187     if e.code == 503:
#
# File /usr/local/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File /usr/local/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:515, in OpenerDirector.open(self, fullurl, data, timeout)
#     512     req = meth(req)
#     514 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 515 response = self._open(req, data)
#     517 # post-process response
#     518 meth_name = protocol+"_response"
#
# File /usr/local/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:532, in OpenerDirector._open(self, req, data)
#     529     return result
#     531 protocol = req.type
# --> 532 result = self._call_chain(self.handle_open, protocol, protocol +
#     533                           '_open', req)
#     534 if result:
#     535     return result
#
# File /usr/local/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File /usr/local/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:1373, in HTTPHandler.http_open(self, req)
#    1372 def http_open(self, req):
# -> 1373     return self.do_open(http.client.HTTPConnection, req)
#
# File /usr/local/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1346     except OSError as err: # timeout error
#    1347         raise URLError(err)
# -> 1348     r = h.getresponse()
#    1349 except:
#    1350     h.close()
#
# File /usr/local/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File /usr/local/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /usr/local/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /usr/local/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/socket.py:708, in SocketIO.readinto(self, b)
#     706 while True:
#     707     try:
# --> 708         return self._sock.recv_into(b)
#     709     except timeout:
#     710         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
df
# Out:
#             id                                              title  \
# 0   2302.09407  fractional marcus-hush-chidsey-yakopcic curren...
# 1   2304.03417  gallium arsenide optical phased array photonic...
# 2   2305.10918  predictions and measurements of thermal conduc...
# 3   2305.13587  single-particle vibrational spectroscopy using...
# 4   2310.16039  modeling of fluctuations in dynamical optoelec...
# ..         ...                                                ...
# 1   2402.17039  incorporating climate change effects into the ...
# 2   2402.18234  extreme ultraviolet lithography reaches 5 nm r...
# 3   2402.18366  estimation of railway vehicle response for tra...
# 4   2402.18421  high-speed cmos compatible plasmonic modulator...
# 5   2402.18492  the electrochemical transistor: a device based...
#
#                                            categories  \
# 0                    cond-mat.mtrl-sci physics.app-ph
# 1                       physics.optics physics.app-ph
# 2   cond-mat.mtrl-sci cond-mat.mes-hall physics.ap...
# 3        physics.optics physics.app-ph physics.bio-ph
# 4              quant-ph physics.app-ph physics.optics
# ..                                                ...
# 1                 physics.soc-ph cs.cy physics.app-ph
# 2                       physics.optics physics.app-ph
# 3                                      physics.app-ph
# 4                       physics.optics physics.app-ph
# 5                        physics.app-ph cond-mat.soft
#
#                                              abstract  \
# 0   we propose a circuit-level model combining the...
# 1   a 16-channel optical phased array is fabricate...
# 2   the lattice thermal conductivity ($\kappa$) of...
# 3   vibrational spectroscopy is a ubiquitous techn...
# 4   we present a full-wave maxwell-density matrix ...
# ..                                                ...
# 1   the demand-supply balance of electricity syste...
# 2   extreme ultraviolet (euv) lithography is the l...
# 3   in railway transportation, the evaluation of t...
# 4   wafer-level testing is an important step for p...
# 5   this work presents an original concept directe...
#
#                             doi     created     updated  \
# 0                                2023-02-18  2024-01-31
# 1             10.1364/oe.492556  2023-04-06
# 2   10.1103/physrevb.108.184306  2023-05-18
# 3    10.1038/s41566-023-01264-3  2023-05-22
# 4                                2023-10-24  2024-01-31
# ..                          ...         ...         ...
# 1   10.1016/j.segan.2020.100403  2024-02-26  2024-02-28
# 2                                2024-02-28
# 3                                2024-02-28
# 4                                2024-02-28
# 5                                2024-02-28
#
#                                               authors
# 0   [georgii paradezhenko, dmitrii prodan, anastas...
# 1   [michael nickerson, bowen song, jim brookhyser...
# 2   [zherui han, zixin xiong, william t. riffe, hu...
# 3   [shui-jing tang, mingjie zhang, jialve sun, ji...
# 4   [johannes popp, johannes stowasser, michael a....
# ..                                                ...
# 1     [inès harang, fabian heymann, laurens p. stoop]
# 2   [iason giannopoulos, iacopo mochi, michaela vo...
# 3    [qingjing wang, wenhao ding, qing he, ping wang]
# 4          [maryam sadat amiri naeini, pierre berini]
# 5   [andrea stefani, agnese giacomino, sara morand...
#
# [297 rows x 8 columns]
